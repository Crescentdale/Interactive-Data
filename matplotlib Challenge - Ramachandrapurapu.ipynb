# %%
import pandas as pd  
from matplotlib import pyplot as plt 
import numpy as np

# %% [markdown]
# I am referring to the **Matplotlib for beginners Cheat Sheet** and Co-pilot to try adding colors into my scatter plot

# %% [markdown]
# I would personally like to learn how to create Pie Chart and Multiple Pie Charts from **5.3 Proportions**. I personally like Pie Charts and I feel that they are visually appealing and provides more information at glance than Bar Charts (again this is subjective). When I learn how to create Pie Chart I would like to showcase data related to Project Management as that is my target career domain and I would like to showcase data on the percentage of PMP and Scrum certification holders in Project Management as currently I am deciding between which one to obtain and I believe this data might help me and others like me get a little more insight into this decision.

# %%
cces = pd.read_csv('cces_example_data.csv')

# %%
fig1, ax1 = plt.subplots(1, 2, figsize = (15, 5))  
ax1[0].set_title('Age Histogram') 
ax1[1].set_title('Political Identity') 
plt.show()

# %%
cces.groupby('Evaluation')

# %%
Evaluation_freq = cces.groupby('Evaluation')['caseid'].count()

# %%
Evaluation_freq
# Out:
# Evaluation
# 0    365
# 1     48
# 2    202
# 3     44
# Name: caseid, dtype: int64

# %%
fig2, ax2 = plt.subplots() 
ax2.bar(x = Evaluation_freq.index, height= Evaluation_freq)  
ax2.set_title('Evaluation Frequencies') 

plt.show()

# %%
fig3, ax3 = plt.subplots()   
ax3.scatter(x = cces['ConMediaUse'] , y = cces['ImmiPhobia'])  
ax3.set_title('ConMediaUse and ImmiPhobia')  
ax3.set_xlabel('ConMediaUse') 
ax3.set_ylabel('ImmiPhobia')
# Out:
# Text(0, 0.5, 'ImmiPhobia')

# %% [markdown]
# I am trying to use colormap for the scatter plot

# %%
x = np.random.rand(659)
y = np.random.rand(659)  
z = np.random.rand(659)

# %%
fig3, ax3 = plt.subplots()   
ax3.scatter(x = cces['ConMediaUse'], y = cces['ImmiPhobia'], c = z, cmap='viridis')  
ax3.set_title('ConMediaUse and ImmiPhobia')  
ax3.set_xlabel('ConMediaUse') 
ax3.set_ylabel('ImmiPhobia')
# Out:
# Text(0, 0.5, 'ImmiPhobia')

# %% [markdown]
# I tried to test the **2.2 Scales map data values onto aesthetics > Colors** by having different colors set for X and Y. However, I was not able to do it and I am not sure if it is feasible or not. I would like to see different colors and shapes for this scatter plot of ConMediaUse and ImmiPhobia. I do not think the data is being overplotted but in case it is, I would like to be able to use the **18.1 Partial transparency and jittering** technique to displace the dots and add transparency for better visualization of data.
